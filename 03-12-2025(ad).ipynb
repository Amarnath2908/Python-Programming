# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("Amazon_electronics.csv")

# %%
df
# Out:
#          item_id  user_id  rating   timestamp model_attr  \
# 0              0        0     5.0  1999-06-13     Female
# 1              0        1     5.0  1999-06-14     Female
# 2              0        2     3.0  1999-06-17     Female
# 3              0        3     1.0  1999-07-01     Female
# 4              0        4     2.0  1999-07-06     Female
# ...          ...      ...     ...         ...        ...
# 1292949     9478  1157628     1.0  2018-09-26     Female
# 1292950     9435  1157629     5.0  2018-09-26     Female
# 1292951     9305  1157630     3.0  2018-09-26     Female
# 1292952     9303  1157631     5.0  2018-09-29       Male
# 1292953     9478  1157632     1.0  2018-10-01     Female
#
#                         category       brand  year user_attr  split
# 0         Portable Audio & Video         NaN  1999       NaN      0
# 1         Portable Audio & Video         NaN  1999       NaN      0
# 2         Portable Audio & Video         NaN  1999       NaN      0
# ...

# %%
df.head(5)
# Out:
#    item_id  user_id  rating   timestamp model_attr                category  \
# 0        0        0     5.0  1999-06-13     Female  Portable Audio & Video
# 1        0        1     5.0  1999-06-14     Female  Portable Audio & Video
# 2        0        2     3.0  1999-06-17     Female  Portable Audio & Video
# 3        0        3     1.0  1999-07-01     Female  Portable Audio & Video
# 4        0        4     2.0  1999-07-06     Female  Portable Audio & Video
#
#   brand  year user_attr  split
# 0   NaN  1999       NaN      0
# 1   NaN  1999       NaN      0
# 2   NaN  1999       NaN      0
# 3   NaN  1999       NaN      0
# 4   NaN  1999       NaN      0

# %%
df.tail(5)
# Out:
#          item_id  user_id  rating   timestamp model_attr  \
# 1292949     9478  1157628     1.0  2018-09-26     Female
# 1292950     9435  1157629     5.0  2018-09-26     Female
# 1292951     9305  1157630     3.0  2018-09-26     Female
# 1292952     9303  1157631     5.0  2018-09-29       Male
# 1292953     9478  1157632     1.0  2018-10-01     Female
#
#                         category       brand  year user_attr  split
# 1292949               Headphones  Etre Jeune  2017       NaN      0
# 1292950  Computers & Accessories         NaN  2017       NaN      0
# 1292951  Computers & Accessories         NaN  2016       NaN      0
# 1292952               Headphones         NaN  2018       NaN      0
# 1292953               Headphones  Etre Jeune  2017    Female      0

# %%
df.shape
# Out:
# (1292954, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1292954 entries, 0 to 1292953
# Data columns (total 10 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   item_id     1292954 non-null  int64
#  1   user_id     1292954 non-null  int64
#  2   rating      1292954 non-null  float64
#  3   timestamp   1292954 non-null  object
#  4   model_attr  1292954 non-null  object
#  5   category    1292954 non-null  object
#  6   brand       331120 non-null   object
#  7   year        1292954 non-null  int64
#  8   user_attr   174124 non-null   object
#  9   split       1292954 non-null  int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 98.6+ MB

# %%
df["category"].unique()
# Out:
# array(['Portable Audio & Video', 'Computers & Accessories', 'Headphones',
#        'Camera & Photo', 'Television & Video', 'Home Audio',
#        'Accessories & Supplies', 'Car Electronics & GPS',
#        'Security & Surveillance', 'Wearable Technology'], dtype=object)

# %%
df.isnull().sum()
# Out:
# item_id             0
# user_id             0
# rating              0
# timestamp           0
# model_attr          0
# category            0
# brand          961834
# year                0
# user_attr     1118830
# split               0
# dtype: int64

# %%
#------------------------------------------------------------------------------------------------------------------------------

# %%
df = pd.read_csv("amazon_products_dataset.csv")

# %%
df
# Out:
#                                title    brand    category  actual_price  \
# 0                Smart Fitness Watch     Dell      Laptop       69890.0
# 1            Laptop with SSD Storage       LG  Smartwatch       66771.0
# 2            High Resolution Monitor       Mi  Headphones       43598.0
# 3                   4K Action Camera       HP      Camera       63408.0
# 4                Smart Fitness Watch  Samsung     Monitor       49224.0
# ...                              ...      ...         ...           ...
# 1995  Smartphone with AMOLED Display     Dell     Monitor       24140.0
# 1996             Smart Fitness Watch       LG  Headphones       65449.0
# 1997                4K Action Camera     Dell  Smartphone       21358.0
# 1998        Noise Cancelling Earbuds  OnePlus  Smartwatch       35229.0
# 1999  Smartphone with AMOLED Display     Boat  Headphones       31662.0
#
#       discount_price  rating  rating_count
# 0            65271.0     2.6        2128.0
# ...

# %%
df.head(5)
# Out:
#                      title    brand    category  actual_price  discount_price  \
# 0      Smart Fitness Watch     Dell      Laptop       69890.0         65271.0
# 1  Laptop with SSD Storage       LG  Smartwatch       66771.0         63977.0
# 2  High Resolution Monitor       Mi  Headphones       43598.0         39679.0
# 3         4K Action Camera       HP      Camera       63408.0         58877.0
# 4      Smart Fitness Watch  Samsung     Monitor       49224.0         45017.0
#
#    rating  rating_count
# 0     2.6        2128.0
# 1     2.5        9118.0
# 2     1.9        2517.0
# 3     3.7       17533.0
# 4     4.9       14228.0

# %%
df.tail(5)
# Out:
#                                title    brand    category  actual_price  \
# 1995  Smartphone with AMOLED Display     Dell     Monitor       24140.0
# 1996             Smart Fitness Watch       LG  Headphones       65449.0
# 1997                4K Action Camera     Dell  Smartphone       21358.0
# 1998        Noise Cancelling Earbuds  OnePlus  Smartwatch       35229.0
# 1999  Smartphone with AMOLED Display     Boat  Headphones       31662.0
#
#       discount_price  rating  rating_count
# 1995         20202.0     3.0       16058.0
# 1996         64559.0     1.1        6655.0
# 1997         18654.0     3.7        5308.0
# 1998         31061.0     2.2       19105.0
# 1999         31047.0     3.2        1064.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           2000 non-null   object
#  1   brand           2000 non-null   object
#  2   category        1998 non-null   object
#  3   actual_price    1998 non-null   float64
#  4   discount_price  1999 non-null   float64
#  5   rating          1996 non-null   float64
#  6   rating_count    1996 non-null   float64
# dtypes: float64(4), object(3)
# memory usage: 109.5+ KB

# %%
df.shape
# Out:
# (2000, 7)

# %%
df["category"].unique()
# Out:
# array(['Laptop', 'Smartwatch', 'Headphones', 'Camera', 'Monitor',
#        'Speaker', 'Tablet', 'Smartphone', nan], dtype=object)

# %%
df.isnull().sum()
# Out:
# title             0
# brand             0
# category          2
# actual_price      2
# discount_price    1
# rating            4
# rating_count      4
# dtype: int64

# %%
df["discount_price"] = df["discount_price"].fillna(df["discount_price"].mean())

# %%
df["rating"] = df["rating"].fillna(df["rating"].median())

# %%
df.isnull().sum()
# Out:
# title             0
# brand             0
# category          2
# actual_price      2
# discount_price    0
# rating            0
# rating_count      4
# dtype: int64

# %%
df["category"] = df["category"].fillna("unknown")

# %%
df
# Out:
#                                title    brand    category  actual_price  \
# 0                Smart Fitness Watch     Dell      Laptop       69890.0
# 1            Laptop with SSD Storage       LG  Smartwatch       66771.0
# 2            High Resolution Monitor       Mi  Headphones       43598.0
# 3                   4K Action Camera       HP      Camera       63408.0
# 4                Smart Fitness Watch  Samsung     Monitor       49224.0
# ...                              ...      ...         ...           ...
# 1995  Smartphone with AMOLED Display     Dell     Monitor       24140.0
# 1996             Smart Fitness Watch       LG  Headphones       65449.0
# 1997                4K Action Camera     Dell  Smartphone       21358.0
# 1998        Noise Cancelling Earbuds  OnePlus  Smartwatch       35229.0
# 1999  Smartphone with AMOLED Display     Boat  Headphones       31662.0
#
#       discount_price  rating  rating_count
# 0            65271.0     2.6        2128.0
# ...

# %%
df.isnull().sum()
# Out:
# title             0
# brand             0
# category          0
# actual_price      2
# discount_price    0
# rating            0
# rating_count      4
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#                                title    brand    category  actual_price  \
# 0                Smart Fitness Watch     Dell      Laptop       69890.0
# 1            Laptop with SSD Storage       LG  Smartwatch       66771.0
# 2            High Resolution Monitor       Mi  Headphones       43598.0
# 3                   4K Action Camera       HP      Camera       63408.0
# 4                Smart Fitness Watch  Samsung     Monitor       49224.0
# ...                              ...      ...         ...           ...
# 1995  Smartphone with AMOLED Display     Dell     Monitor       24140.0
# 1996             Smart Fitness Watch       LG  Headphones       65449.0
# 1997                4K Action Camera     Dell  Smartphone       21358.0
# 1998        Noise Cancelling Earbuds  OnePlus  Smartwatch       35229.0
# 1999  Smartphone with AMOLED Display     Boat  Headphones       31662.0
#
#       discount_price  rating  rating_count
# 0            65271.0     2.6        2128.0
# ...

# %%
df
# Out:
#                                title    brand    category  actual_price  \
# 0                Smart Fitness Watch     Dell      Laptop       69890.0
# 1            Laptop with SSD Storage       LG  Smartwatch       66771.0
# 2            High Resolution Monitor       Mi  Headphones       43598.0
# 3                   4K Action Camera       HP      Camera       63408.0
# 4                Smart Fitness Watch  Samsung     Monitor       49224.0
# ...                              ...      ...         ...           ...
# 1995  Smartphone with AMOLED Display     Dell     Monitor       24140.0
# 1996             Smart Fitness Watch       LG  Headphones       65449.0
# 1997                4K Action Camera     Dell  Smartphone       21358.0
# 1998        Noise Cancelling Earbuds  OnePlus  Smartwatch       35229.0
# 1999  Smartphone with AMOLED Display     Boat  Headphones       31662.0
#
#       discount_price  rating  rating_count
# 0            65271.0     2.6        2128.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           2000 non-null   object
#  1   brand           2000 non-null   object
#  2   category        2000 non-null   object
#  3   actual_price    1998 non-null   float64
#  4   discount_price  2000 non-null   float64
#  5   rating          2000 non-null   float64
#  6   rating_count    1996 non-null   float64
# dtypes: float64(4), object(3)
# memory usage: 109.5+ KB

# %%
df = df.apply(pd.to_numeric, errors='ignore')
# Out:
# C:\Users\bojja\AppData\Local\Temp\ipykernel_16912\3283324713.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           2000 non-null   object
#  1   brand           2000 non-null   object
#  2   category        2000 non-null   object
#  3   actual_price    1998 non-null   float64
#  4   discount_price  2000 non-null   float64
#  5   rating          2000 non-null   float64
#  6   rating_count    1996 non-null   float64
# dtypes: float64(4), object(3)
# memory usage: 109.5+ KB

# %%
df.reset_index(drop=True)
# Out:
#                                title    brand    category  actual_price  \
# 0                Smart Fitness Watch     Dell      Laptop       69890.0
# 1            Laptop with SSD Storage       LG  Smartwatch       66771.0
# 2            High Resolution Monitor       Mi  Headphones       43598.0
# 3                   4K Action Camera       HP      Camera       63408.0
# 4                Smart Fitness Watch  Samsung     Monitor       49224.0
# ...                              ...      ...         ...           ...
# 1995  Smartphone with AMOLED Display     Dell     Monitor       24140.0
# 1996             Smart Fitness Watch       LG  Headphones       65449.0
# 1997                4K Action Camera     Dell  Smartphone       21358.0
# 1998        Noise Cancelling Earbuds  OnePlus  Smartwatch       35229.0
# 1999  Smartphone with AMOLED Display     Boat  Headphones       31662.0
#
#       discount_price  rating  rating_count
# 0            65271.0     2.6        2128.0
# ...

# %%
df["actual_price"].sort_values(ascending=False).head(5)
# Out:
# 1383    79993.0
# 1974    79869.0
# 1403    79857.0
# 1351    79853.0
# 42      79826.0
# Name: actual_price, dtype: float64

# %%
x = df.groupby("brand")["category"].count()

# %%
x
# Out:
# brand
# Apple      190
# Boat       214
# Dell       177
# HP         206
# JBL        207
# LG         208
# Mi         181
# OnePlus    204
# Samsung    205
# Sony       208
# Name: category, dtype: int64

# %%
x.max()
# Out:
# 214

# %%
x.idxmax()
# Out:
# 'Boat'

# %%
df
# Out:
#                                title    brand    category  actual_price  \
# 0                Smart Fitness Watch     Dell      Laptop       69890.0
# 1            Laptop with SSD Storage       LG  Smartwatch       66771.0
# 2            High Resolution Monitor       Mi  Headphones       43598.0
# 3                   4K Action Camera       HP      Camera       63408.0
# 4                Smart Fitness Watch  Samsung     Monitor       49224.0
# ...                              ...      ...         ...           ...
# 1995  Smartphone with AMOLED Display     Dell     Monitor       24140.0
# 1996             Smart Fitness Watch       LG  Headphones       65449.0
# 1997                4K Action Camera     Dell  Smartphone       21358.0
# 1998        Noise Cancelling Earbuds  OnePlus  Smartwatch       35229.0
# 1999  Smartphone with AMOLED Display     Boat  Headphones       31662.0
#
#       discount_price  rating  rating_count
# 0            65271.0     2.6        2128.0
# ...

# %%
df.isnull().sum()
# Out:
# title             0
# brand             0
# category          0
# actual_price      2
# discount_price    0
# rating            0
# rating_count      4
# dtype: int64

# %%
df = df.dropna()

# %%
df
# Out:
#                                title    brand    category  actual_price  \
# 0                Smart Fitness Watch     Dell      Laptop       69890.0
# 1            Laptop with SSD Storage       LG  Smartwatch       66771.0
# 2            High Resolution Monitor       Mi  Headphones       43598.0
# 3                   4K Action Camera       HP      Camera       63408.0
# 4                Smart Fitness Watch  Samsung     Monitor       49224.0
# ...                              ...      ...         ...           ...
# 1995  Smartphone with AMOLED Display     Dell     Monitor       24140.0
# 1996             Smart Fitness Watch       LG  Headphones       65449.0
# 1997                4K Action Camera     Dell  Smartphone       21358.0
# 1998        Noise Cancelling Earbuds  OnePlus  Smartwatch       35229.0
# 1999  Smartphone with AMOLED Display     Boat  Headphones       31662.0
#
#       discount_price  rating  rating_count
# 0            65271.0     2.6        2128.0
# ...

# %%
df.isnull().sum()
# Out:
# title             0
# brand             0
# category          0
# actual_price      0
# discount_price    0
# rating            0
# rating_count      0
# dtype: int64

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#                                title    brand    category  actual_price  \
# 0                Smart Fitness Watch     Dell      Laptop       69890.0
# 1            Laptop with SSD Storage       LG  Smartwatch       66771.0
# 2            High Resolution Monitor       Mi  Headphones       43598.0
# 3                   4K Action Camera       HP      Camera       63408.0
# 4                Smart Fitness Watch  Samsung     Monitor       49224.0
# ...                              ...      ...         ...           ...
# 1989  Smartphone with AMOLED Display     Dell     Monitor       24140.0
# 1990             Smart Fitness Watch       LG  Headphones       65449.0
# 1991                4K Action Camera     Dell  Smartphone       21358.0
# 1992        Noise Cancelling Earbuds  OnePlus  Smartwatch       35229.0
# 1993  Smartphone with AMOLED Display     Boat  Headphones       31662.0
#
#       discount_price  rating  rating_count
# 0            65271.0     2.6        2128.0
# ...

# %%
df["actual_price"].sort_values(ascending=False).head(5)
# Out:
# 1377    79993.0
# 1968    79869.0
# 1397    79857.0
# 1345    79853.0
# 42      79826.0
# Name: actual_price, dtype: float64

# %%
x = df.groupby("brand")["category"].count()

# %%
x.max()
# Out:
# 213

# %%
x.idxmax()
# Out:
# 'Boat'

# %%
y = df.groupby("brand")["discount_price"].mean()

# %%
y
# Out:
# brand
# Apple      35879.227513
# Boat       36304.585915
# Dell       37570.078531
# HP         38354.180583
# JBL        37380.390821
# LG         35147.757561
# Mi         36542.437569
# OnePlus    39090.550490
# Samsung    37933.346049
# Sony       36940.807246
# Name: discount_price, dtype: float64

# %%
high_rated_products = df[(df['rating'] >= 4.5) & (df['rating_count'] >= 2000)]
high_rated_products
# Out:
#                                title    brand    category  actual_price  \
# 4                Smart Fitness Watch  Samsung     Monitor       49224.0
# 32                  4K Action Camera  OnePlus  Smartphone        7793.0
# 51     Wireless Bluetooth Headphones     Dell  Headphones       61569.0
# 52           Laptop with SSD Storage     Boat  Smartwatch       76286.0
# 59                     Gaming Laptop  Samsung      Tablet       45250.0
# ...                              ...      ...         ...           ...
# 1943      Portable Bluetooth Speaker  OnePlus      Tablet       59325.0
# 1964                  Android Tablet     Boat      Camera       20841.0
# 1969   Wireless Bluetooth Headphones  Samsung  Smartwatch       31973.0
# 1976   Wireless Bluetooth Headphones       HP      Camera       15343.0
# 1982  Smartphone with AMOLED Display       LG      Tablet       29783.0
#
#       discount_price  rating  rating_count
# 4            45017.0     4.9       14228.0
# ...

# %%
category_avg_price = df.groupby('category')['actual_price'].mean().sort_values(ascending=False)

# %%
category_avg_price
# Out:
# category
# Laptop        40786.508403
# Camera        40365.992157
# Monitor       39950.747212
# Tablet        39865.258182
# Speaker       39683.795276
# Headphones    39576.147679
# Smartwatch    38300.609053
# Smartphone    37909.529412
# unknown       33610.500000
# Name: actual_price, dtype: float64

# %%
df["discount_percent"] = ((df["actual_price"] - df["discount_price"]) / df["actual_price"]) * 100

# %%
discount_percent
# Out:
# 0        6.608957
# 1        4.184451
# 2        8.988944
# 3        7.145786
# 4        8.546644
#           ...
# 1989    16.313173
# 1990     1.359837
# 1991    12.660361
# 1992    11.831162
# 1993     1.942392
# Length: 1994, dtype: float64

# %%
df['price_category'] = pd.cut(df['actual_price'],
                              bins=[0, 500, 2000, np.inf],
                              labels=["Budget", "Midrange", "Premium"],
                              right=False)

# %%
df
# Out:
#                                title    brand    category  actual_price  \
# 0                Smart Fitness Watch     Dell      Laptop       69890.0
# 1            Laptop with SSD Storage       LG  Smartwatch       66771.0
# 2            High Resolution Monitor       Mi  Headphones       43598.0
# 3                   4K Action Camera       HP      Camera       63408.0
# 4                Smart Fitness Watch  Samsung     Monitor       49224.0
# ...                              ...      ...         ...           ...
# 1989  Smartphone with AMOLED Display     Dell     Monitor       24140.0
# 1990             Smart Fitness Watch       LG  Headphones       65449.0
# 1991                4K Action Camera     Dell  Smartphone       21358.0
# 1992        Noise Cancelling Earbuds  OnePlus  Smartwatch       35229.0
# 1993  Smartphone with AMOLED Display     Boat  Headphones       31662.0
#
#       discount_price  rating  rating_count price_category  popularity_score  \
# ...

# %%
df['popularity_score'] = df['rating'] * np.log(df['rating_count'] + 1)

# %%
df
# Out:
#                                title    brand    category  actual_price  \
# 0                Smart Fitness Watch     Dell      Laptop       69890.0
# 1            Laptop with SSD Storage       LG  Smartwatch       66771.0
# 2            High Resolution Monitor       Mi  Headphones       43598.0
# 3                   4K Action Camera       HP      Camera       63408.0
# 4                Smart Fitness Watch  Samsung     Monitor       49224.0
# ...                              ...      ...         ...           ...
# 1989  Smartphone with AMOLED Display     Dell     Monitor       24140.0
# 1990             Smart Fitness Watch       LG  Headphones       65449.0
# 1991                4K Action Camera     Dell  Smartphone       21358.0
# 1992        Noise Cancelling Earbuds  OnePlus  Smartwatch       35229.0
# 1993  Smartphone with AMOLED Display     Boat  Headphones       31662.0
#
#       discount_price  rating  rating_count price_category  popularity_score  \
# ...

# %%
t = df.sort_values(by='popularity_score', ascending=False).head(10)

# %%
t[['category', 'brand', 'popularity_score', 'price_category', 'discount_percent']]
# Out:
#         category    brand  popularity_score price_category  discount_percent
# 1412      Laptop  OnePlus         49.130602        Premium          2.128500
# 297       Camera  Samsung         48.928304        Premium          8.183939
# 501       Camera  Samsung         48.625690        Premium         17.611155
# 1394  Headphones     Dell         48.388891        Premium         23.746032
# 872   Smartwatch    Apple         48.248857        Premium         41.073039
# 1483      Laptop    Apple         48.240292        Premium          6.383861
# 843   Smartphone       HP         48.157775        Premium         20.686106
# 849   Smartwatch  Samsung         48.040676        Premium         24.030284
# 1619      Tablet     Dell         47.848110        Premium         19.040996
# 634   Headphones     Dell         47.803700        Premium          5.365394

# %%
a = df.sort_values(by = "discount_percent",ascending=False)

# %%
a
# Out:
#                                title    brand    category  actual_price  \
# 20                  4K Action Camera  OnePlus  Headphones        4378.0
# 74           High Resolution Monitor     Boat     Monitor        5137.0
# 829                 4K Action Camera  OnePlus     Monitor        3414.0
# 1305        Noise Cancelling Earbuds    Apple  Smartwatch        3791.0
# 1828   Wireless Bluetooth Headphones     Boat  Headphones        5377.0
# ...                              ...      ...         ...           ...
# 1530        Noise Cancelling Earbuds     Sony     Monitor       53009.0
# 174          High Resolution Monitor       HP  Smartphone       73673.0
# 685   Smartphone with AMOLED Display       LG  Headphones       68989.0
# 1389                   Gaming Laptop  OnePlus  Headphones       79680.0
# 1079  Smartphone with AMOLED Display  Samsung     Monitor        9345.0
#
#       discount_price  rating  rating_count price_category  popularity_score  \
# ...

# %%
b = a[(a["price_category"] == "Premium") & (a["discount_percent"] > 40)]

# %%
b
# Out:
#                               title    brand    category  actual_price  \
# 20                 4K Action Camera  OnePlus  Headphones        4378.0
# 74          High Resolution Monitor     Boat     Monitor        5137.0
# 829                4K Action Camera  OnePlus     Monitor        3414.0
# 1305       Noise Cancelling Earbuds    Apple  Smartwatch        3791.0
# 1828  Wireless Bluetooth Headphones     Boat  Headphones        5377.0
# ...                             ...      ...         ...           ...
# 791             Smart Fitness Watch       LG     Speaker        9496.0
# 872         Laptop with SSD Storage    Apple  Smartwatch        4436.0
# 683      Portable Bluetooth Speaker     Boat      Tablet       11823.0
# 1749  Wireless Bluetooth Headphones  Samsung      Laptop       11737.0
# 1273            Smart Fitness Watch  OnePlus  Smartwatch       11632.0
#
#       discount_price  rating  rating_count price_category  popularity_score  \
# ...

# %%
bluetooth_products = df[df['title'].str.contains('Bluetooth', case=False, na=False)]

# %%
bluetooth_products
# Out:
#                               title    brand    category  actual_price  \
# 14       Portable Bluetooth Speaker  OnePlus      Camera       25516.0
# 18       Portable Bluetooth Speaker     Sony     Monitor       73590.0
# 21    Wireless Bluetooth Headphones  Samsung     Speaker       78689.0
# 23       Portable Bluetooth Speaker       HP  Smartwatch        4342.0
# 25    Wireless Bluetooth Headphones     Boat     Monitor       14689.0
# ...                             ...      ...         ...           ...
# 1969  Wireless Bluetooth Headphones  Samsung  Smartwatch       31973.0
# 1973  Wireless Bluetooth Headphones     Sony     Monitor       65124.0
# 1976  Wireless Bluetooth Headphones       HP      Camera       15343.0
# 1979  Wireless Bluetooth Headphones       Mi  Smartwatch       50527.0
# 1980     Portable Bluetooth Speaker  Samsung     Monitor       53328.0
#
#       discount_price  rating  rating_count price_category  popularity_score  \
# ...

# %%
p = df['popularity_score'].quantile(0.70)

f = df[
    (df['rating'] >= 4.0) &
    (df['discount_percent'].between(20, 50)) &
    (df['popularity_score'] >= p)
]

# %%
f
# Out:
#                                title    brand    category  actual_price  \
# 32                  4K Action Camera  OnePlus  Smartphone        7793.0
# 94               Smart Fitness Watch       HP     Monitor       16289.0
# 107          High Resolution Monitor      JBL  Smartphone        7308.0
# 140                    Gaming Laptop     Sony      Tablet       11869.0
# 162                   Android Tablet    Apple     Speaker       11918.0
# 165    Wireless Bluetooth Headphones    Apple  Smartwatch        7654.0
# 188       Portable Bluetooth Speaker       LG  Smartphone       10227.0
# 215    Wireless Bluetooth Headphones    Apple      Camera       16855.0
# 274   Smartphone with AMOLED Display     Sony     Speaker        6770.0
# 403       Portable Bluetooth Speaker  Samsung      Laptop       14978.0
# 468                   Android Tablet     Boat      Laptop        8287.0
# 479          Laptop with SSD Storage       HP     Monitor         366.0
# ...

# %%
f.shape
# Out:
# (54, 10)
